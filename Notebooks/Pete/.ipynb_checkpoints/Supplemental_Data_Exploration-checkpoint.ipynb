# %% [markdown]
# # Supplemental Data Exploration:
#
# ## Categorical Variables, SPLOM

# %%
import sys
PATH_TO_MODULES = '../..'
sys.path.insert(0, PATH_TO_MODULES)

from helpers import get_quarters

# Data Manipulation and Math/Stats Libraries
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm

# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import plotly.express as px
import plotly.graph_objects as go

# %%
def plot_categorical_dist(feature):
    """Plot a distribution (histogram) for a categorical feature."""
    fig = px.histogram(
        dataset,
        x=feature, y='Ticker', histfunc='count',
        title='Distribution of Companies by ' + feature,
        width=600, height=400
    )
    fig.update_layout(title_pad_l=120)
    fig.show()
    return None

# %%
# Import data
path = PATH_TO_MODULES + '/datasets/'
filename = 'Russell_3000_Cleaned.csv'
dataset = pd.read_csv(path + filename)

# %%
quarters = get_quarters(dataset)
print(quarters)
# Out:
# ['_2024Q2', '_2024Q3', '_2024Q4', '_2025Q1', '_2025Q2']

# %% [markdown]
# ## Company Demographics
#
# Let's examine company financials in the context of different categorical variables.
#
# Three are relevant: Sector, Exchange, and Location.

# %% [markdown]
# ### Market Cap

# %%
plot_categorical_dist('Market Cap')

# %% [markdown]
# ### Sector

# %%
plot_categorical_dist('Sector')

# %%
quarter = '2025Q2'
columns = [f'Revenue_{quarter}',
           f'OperatingIncome_{quarter}',
           f'NetIncome_{quarter}',
           f'CashFromOps_{quarter}',
           f'CashAndSTInvestments_{quarter}',
           f'LongTermDebt_{quarter}',
           f'TotalAssets_{quarter}',
           f'TotalLiabilities_{quarter}',
           f'EPS_{quarter}'
          ]

fig = px.scatter_matrix(
    dataset,
    dimensions=columns,
    color='Sector',
    width=1280, height=720
)
fig.show()

# %% [markdown]
# A few of the financial companies seem to really stand out...

# %% [markdown]
# ### Exchange

# %%
# Plot the distribution by exchange
plot_categorical_dist('Exchange')

# %%
quarter = '2025Q2'
columns = [f'Revenue_{quarter}',
           f'OperatingIncome_{quarter}',
           f'NetIncome_{quarter}',
           f'CashFromOps_{quarter}',
           f'CashAndSTInvestments_{quarter}',
           f'LongTermDebt_{quarter}',
           f'TotalAssets_{quarter}',
           f'TotalLiabilities_{quarter}',
           f'EPS_{quarter}'
          ]

fig = px.scatter_matrix(
    dataset,
    dimensions=columns,
    color='Exchange',
    width=1280, height=720
)
fig.show()

# %% [markdown]
# ### Check EPS data

# %%
dataset[['EPS' + quarter for quarter in quarters]].describe()
# Out:
#         EPS_2024Q2   EPS_2024Q3   EPS_2024Q4   EPS_2025Q1   EPS_2025Q2
# count  2267.000000  2374.000000  2203.000000  2372.000000  2379.000000
# mean      0.702013     0.852982     0.766677     0.672181     0.831920
# std       4.023053     4.148967     5.087371     2.849926     3.934059
# min     -76.260000   -16.440000   -55.660000   -21.080000   -77.700000
# 25%      -0.010000    -0.030000    -0.030000    -0.040000     0.000000
# 50%       0.370000     0.360000     0.380000     0.320000     0.410000
# 75%       1.100000     1.111706     1.160000     1.042500     1.200000
# max     120.690000   130.500000   139.930000    94.830000   108.540000

# %%
dataset['EPS' + quarters[0]]
# Out:
# 0        NaN
# 1       2.95
# 2       1.40
# 3       1.26
# 4       5.16
#         ...
# 2416    0.95
# 2417     NaN
# 2418     NaN
# 2419   -0.14
# 2420     NaN
# Name: EPS_2024Q2, Length: 2421, dtype: float64
