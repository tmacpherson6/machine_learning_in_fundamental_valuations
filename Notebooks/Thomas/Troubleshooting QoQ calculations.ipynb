# %% [markdown]
# # Troubleshooting QoQ Calculations
# In the cleaning file we removed all raw NaN values, so something seems to be going wrong in the QoQ feature engineering file that is leading to the introduction of novel NaN values. I'm going to use this notebook to investigate the potential reasons as to why that is happening. Let's start by importing some data-manipulation libraries.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Now, let's import the files that we will be working with.

# %%
path = '../../datasets/X_train_filled_KPIs_QoQ.csv'
df = pd.read_csv(path, index_col=0)
df.head()
# Out:
#                                   Name                  Sector  \
# Ticker
# CAL                        CALERES INC  Consumer Discretionary
# BLDR          BUILDERS FIRSTSOURCE INC             Industrials
# PR      PERMIAN RESOURCES CORP CLASS A                  Energy
# AVTR                       AVANTOR INC             Health Care
# KRYS               KRYSTAL BIOTECH INC             Health Care
#
#         CapitalExpenditure_2024Q2  CapitalExpenditure_2024Q3  \
# Ticker
# CAL                    -8754000.0              -1.148200e+07
# BLDR                  -88107000.0              -9.957800e+07
# PR                   -682937000.0              -1.277047e+09
# AVTR                  -45800000.0              -4.080000e+07
# KRYS                   -1131000.0              -1.046000e+06
#
#         CapitalExpenditure_2024Q4  CapitalExpenditure_2025Q1  \
# Ticker
# CAL                   -18520000.0                -11358000.0
# BLDR                  -99672000.0                -99974000.0
# PR                   -541242000.0               -537805000.0
# AVTR                  -27500000.0                -28000000.0
# KRYS                    -801000.0                 -6204000.0
#
#         CashAndSTInvestments_2024Q2  CashAndSTInvestments_2024Q3  \
# Ticker
# CAL                      68348500.0                   51753000.0
# BLDR                     75569000.0                  328103000.0
# PR                       47849000.0                  272026000.0
# AVTR                    272600000.0                  285300000.0
# KRYS                    345786000.0                  373966000.0
#
#         CashAndSTInvestments_2024Q4  CashAndSTInvestments_2025Q1  ...  \
# Ticker                                                            ...
# CAL                      33685000.0                   29636000.0  ...
# BLDR                    153624000.0                  115371000.0  ...
# PR                      479343000.0                  702236000.0  ...
# AVTR                    261900000.0                  315700000.0  ...
# KRYS                    344865000.0                  308770000.0  ...
#
#         TotalLiabilities_Rate  LongTermDebt_Rate  OtherOperatingExpense_Rate  \
# Ticker
# CAL               185979300.0         57693950.0                  55284650.0
# BLDR              180988200.0        201455700.0                 -15548600.0
# PR                169910900.0        -48511400.0                   1116000.0
# AVTR             -422050000.0       -618890000.0                 -12300000.0
# KRYS                4591700.0           578200.0                   1389400.0
#
#         KPI_CashFlow_Rate  KPI_DebtToEquityRatio_Rate  IncomeTaxExpense_Rate  \
# Ticker
# CAL            -9265050.0                   -0.021142             -1271100.0
# BLDR         -131576300.0                    0.050365            -23858000.0
# PR            -20398600.0                   -0.009237              1036300.0
# AVTR          -58690000.0                   -0.100838              6560000.0
# KRYS            9939700.0                    0.000118              2270300.0
#
#         Revenue_Rate  KPI_NetProfitMargin_Rate  TotalAssets_Rate  \
# Ticker
# CAL      143455800.0                 -0.005052       300724300.0
# BLDR    -280872000.0                 -0.017014       186823300.0
# PR        47161400.0                  0.000100       528553000.0
# AVTR     -39200000.0                  0.022167      -182740000.0
# KRYS       6099500.0                  0.072596        54379400.0
#
#         CashFromOps_Rate
# Ticker
# CAL           -9265050.0
# BLDR        -131576300.0
# PR           -20398600.0
# AVTR         -58690000.0
# KRYS           9939700.0
#
# [5 rows x 282 columns]

# %% [markdown]
# Let's grab all columns so that if we need to use some we can easily reference this list

# %%
columns = df.columns.tolist()
for col in sorted(columns):
    print(col)
# Out:
# CapitalExpenditure_2024Q2
# CapitalExpenditure_2024Q3
# CapitalExpenditure_2024Q4
# CapitalExpenditure_2025Q1
# CapitalExpenditure_QoQ_24Q2_24Q3
# CapitalExpenditure_QoQ_24Q3_24Q4
# CapitalExpenditure_QoQ_24Q4_25Q1
# CapitalExpenditure_QoQ_Rate
# CapitalExpenditure_Rate
# CashAndSTInvestments_2024Q2
# CashAndSTInvestments_2024Q3
# CashAndSTInvestments_2024Q4
# CashAndSTInvestments_2025Q1
# CashAndSTInvestments_QoQ_24Q2_24Q3
# CashAndSTInvestments_QoQ_24Q3_24Q4
# CashAndSTInvestments_QoQ_24Q4_25Q1
# CashAndSTInvestments_QoQ_Rate
# CashAndSTInvestments_Rate
# CashFromOps_2024Q2
# CashFromOps_2024Q3
# CashFromOps_2024Q4
# CashFromOps_2025Q1
# CashFromOps_QoQ_24Q2_24Q3
# CashFromOps_QoQ_24Q3_24Q4
# CashFromOps_QoQ_24Q4_25Q1
# CashFromOps_QoQ_Rate
# CashFromOps_Rate
# CostOfRevenue_2024Q2
# CostOfRevenue_2024Q3
# CostOfRevenue_2024Q4
# CostOfRevenue_2025Q1
# CostOfRevenue_QoQ_24Q2_24Q3
# CostOfRevenue_QoQ_24Q3_24Q4
# CostOfRevenue_QoQ_24Q4_25Q1
# CostOfRevenue_QoQ_Rate
# CostOfRevenue_Rate
# CurrentAssets_2024Q2
# CurrentAssets_2024Q3
# CurrentAssets_2024Q4
# CurrentAssets_2025Q1
# CurrentAssets_QoQ_24Q2_24Q3
# CurrentAssets_QoQ_24Q3_24Q4
# CurrentAssets_QoQ_24Q4_25Q1
# CurrentAssets_QoQ_Rate
# CurrentAssets_Rate
# CurrentLiabilities_2024Q2
# CurrentLiabilities_2024Q3
# CurrentLiabilities_2024Q4
# CurrentLiabilities_2025Q1
# CurrentLiabilities_QoQ_24Q2_24Q3
# CurrentLiabilities_QoQ_24Q3_24Q4
# CurrentLiabilities_QoQ_24Q4_25Q1
# CurrentLiabilities_QoQ_Rate
# CurrentLiabilities_Rate
# EPS_2024Q2
# EPS_2024Q3
# EPS_2024Q4
# EPS_2025Q1
# EPS_QoQ_24Q2_24Q3
# EPS_QoQ_24Q3_24Q4
# EPS_QoQ_24Q4_25Q1
# EPS_QoQ_Rate
# EPS_Rate
# Exchange
# GDPReal_2024Q1
# GDPReal_2024Q2
# GDPReal_2024Q3
# GDPReal_2024Q4
# GDPReal_2025Q1
# GDP_2024Q1
# GDP_2024Q2
# GDP_2024Q3
# GDP_2024Q4
# GDP_2025Q1
# IncomeTaxExpense_2024Q2
# IncomeTaxExpense_2024Q3
# IncomeTaxExpense_2024Q4
# IncomeTaxExpense_2025Q1
# IncomeTaxExpense_QoQ_24Q2_24Q3
# IncomeTaxExpense_QoQ_24Q3_24Q4
# IncomeTaxExpense_QoQ_24Q4_25Q1
# IncomeTaxExpense_QoQ_Rate
# IncomeTaxExpense_Rate
# IndustrialProd_2024Q1
# IndustrialProd_2024Q2
# IndustrialProd_2024Q3
# IndustrialProd_2024Q4
# IndustrialProd_2025Q1
# Inflation_2024Q1
# Inflation_2024Q2
# Inflation_2024Q3
# Inflation_2024Q4
# Inflation_2025Q1
# InterestExpense_2024Q2
# InterestExpense_2024Q3
# InterestExpense_2024Q4
# InterestExpense_2025Q1
# InterestExpense_QoQ_24Q2_24Q3
# InterestExpense_QoQ_24Q3_24Q4
# InterestExpense_QoQ_24Q4_25Q1
# InterestExpense_QoQ_Rate
# InterestExpense_Rate
# InterestRate_2024Q1
# InterestRate_2024Q2
# InterestRate_2024Q3
# InterestRate_2024Q4
# InterestRate_2025Q1
# KPI_CashFlow_2024Q2
# KPI_CashFlow_2024Q3
# KPI_CashFlow_2024Q4
# KPI_CashFlow_2025Q1
# KPI_CashFlow_QoQ_24Q2_24Q3
# KPI_CashFlow_QoQ_24Q3_24Q4
# KPI_CashFlow_QoQ_24Q4_25Q1
# KPI_CashFlow_QoQ_Rate
# KPI_CashFlow_Rate
# KPI_CurrentRatio_2024Q2
# KPI_CurrentRatio_2024Q3
# KPI_CurrentRatio_2024Q4
# KPI_CurrentRatio_2025Q1
# KPI_CurrentRatio_QoQ_24Q2_24Q3
# KPI_CurrentRatio_QoQ_24Q3_24Q4
# KPI_CurrentRatio_QoQ_24Q4_25Q1
# KPI_CurrentRatio_QoQ_Rate
# KPI_CurrentRatio_Rate
# KPI_DebtToEquityRatio_2024Q2
# KPI_DebtToEquityRatio_2024Q3
# KPI_DebtToEquityRatio_2024Q4
# KPI_DebtToEquityRatio_2025Q1
# KPI_DebtToEquityRatio_QoQ_24Q2_24Q3
# KPI_DebtToEquityRatio_QoQ_24Q3_24Q4
# KPI_DebtToEquityRatio_QoQ_24Q4_25Q1
# KPI_DebtToEquityRatio_QoQ_Rate
# KPI_DebtToEquityRatio_Rate
# KPI_GrossProfitMargin_2024Q2
# KPI_GrossProfitMargin_2024Q3
# KPI_GrossProfitMargin_2024Q4
# KPI_GrossProfitMargin_2025Q1
# KPI_GrossProfitMargin_QoQ_24Q2_24Q3
# KPI_GrossProfitMargin_QoQ_24Q3_24Q4
# KPI_GrossProfitMargin_QoQ_24Q4_25Q1
# KPI_GrossProfitMargin_QoQ_Rate
# KPI_GrossProfitMargin_Rate
# KPI_Leverage_2024Q2
# KPI_Leverage_2024Q3
# KPI_Leverage_2024Q4
# KPI_Leverage_2025Q1
# KPI_Leverage_QoQ_24Q2_24Q3
# KPI_Leverage_QoQ_24Q3_24Q4
# KPI_Leverage_QoQ_24Q4_25Q1
# KPI_Leverage_QoQ_Rate
# KPI_Leverage_Rate
# KPI_NetProfitMargin_2024Q2
# KPI_NetProfitMargin_2024Q3
# KPI_NetProfitMargin_2024Q4
# KPI_NetProfitMargin_2025Q1
# KPI_NetProfitMargin_QoQ_24Q2_24Q3
# KPI_NetProfitMargin_QoQ_24Q3_24Q4
# KPI_NetProfitMargin_QoQ_24Q4_25Q1
# KPI_NetProfitMargin_QoQ_Rate
# KPI_NetProfitMargin_Rate
# KPI_ReturnOnAssets_2024Q3
# KPI_ReturnOnAssets_2024Q4
# KPI_ReturnOnAssets_2025Q1
# KPI_ReturnOnAssets_QoQ_24Q3_24Q4
# KPI_ReturnOnAssets_QoQ_24Q4_25Q1
# KPI_ReturnOnAssets_QoQ_Rate
# KPI_ReturnOnAssets_Rate
# KPI_ReturnOnEquity_2024Q3
# KPI_ReturnOnEquity_2024Q4
# KPI_ReturnOnEquity_2025Q1
# KPI_ReturnOnEquity_QoQ_24Q3_24Q4
# KPI_ReturnOnEquity_QoQ_24Q4_25Q1
# KPI_ReturnOnEquity_QoQ_Rate
# KPI_ReturnOnEquity_Rate
# KPI_TotalAssetTurnover_2024Q3
# KPI_TotalAssetTurnover_2024Q4
# KPI_TotalAssetTurnover_2025Q1
# KPI_TotalAssetTurnover_QoQ_24Q3_24Q4
# KPI_TotalAssetTurnover_QoQ_24Q4_25Q1
# KPI_TotalAssetTurnover_QoQ_Rate
# KPI_TotalAssetTurnover_Rate
# KPI_WorkingCapital_2024Q2
# KPI_WorkingCapital_2024Q3
# KPI_WorkingCapital_2024Q4
# KPI_WorkingCapital_2025Q1
# KPI_WorkingCapital_QoQ_24Q2_24Q3
# KPI_WorkingCapital_QoQ_24Q3_24Q4
# KPI_WorkingCapital_QoQ_24Q4_25Q1
# KPI_WorkingCapital_QoQ_Rate
# KPI_WorkingCapital_Rate
# Location
# LongTermDebt_2024Q2
# LongTermDebt_2024Q3
# LongTermDebt_2024Q4
# LongTermDebt_2025Q1
# LongTermDebt_QoQ_24Q2_24Q3
# LongTermDebt_QoQ_24Q3_24Q4
# LongTermDebt_QoQ_24Q4_25Q1
# LongTermDebt_QoQ_Rate
# LongTermDebt_Rate
# Market Cap
# Market Value
# Name
# NetIncome_2024Q2
# NetIncome_2024Q3
# NetIncome_2024Q4
# NetIncome_2025Q1
# NetIncome_QoQ_24Q2_24Q3
# NetIncome_QoQ_24Q3_24Q4
# NetIncome_QoQ_24Q4_25Q1
# NetIncome_QoQ_Rate
# NetIncome_Rate
# OperatingIncome_2024Q2
# OperatingIncome_2024Q3
# OperatingIncome_2024Q4
# OperatingIncome_2025Q1
# OperatingIncome_QoQ_24Q2_24Q3
# OperatingIncome_QoQ_24Q3_24Q4
# OperatingIncome_QoQ_24Q4_25Q1
# OperatingIncome_QoQ_Rate
# OperatingIncome_Rate
# OtherOperatingExpense_2024Q2
# OtherOperatingExpense_2024Q3
# OtherOperatingExpense_2024Q4
# OtherOperatingExpense_2025Q1
# OtherOperatingExpense_QoQ_24Q2_24Q3
# OtherOperatingExpense_QoQ_24Q3_24Q4
# OtherOperatingExpense_QoQ_24Q4_25Q1
# OtherOperatingExpense_QoQ_Rate
# OtherOperatingExpense_Rate
# Revenue_2024Q2
# Revenue_2024Q3
# Revenue_2024Q4
# Revenue_2025Q1
# Revenue_QoQ_24Q2_24Q3
# Revenue_QoQ_24Q3_24Q4
# Revenue_QoQ_24Q4_25Q1
# Revenue_QoQ_Rate
# Revenue_Rate
# Sector
# TotalAssets_2024Q2
# TotalAssets_2024Q3
# TotalAssets_2024Q4
# TotalAssets_2025Q1
# TotalAssets_QoQ_24Q2_24Q3
# TotalAssets_QoQ_24Q3_24Q4
# TotalAssets_QoQ_24Q4_25Q1
# TotalAssets_QoQ_Rate
# TotalAssets_Rate
# TotalDebt_2024Q2
# TotalDebt_2024Q3
# TotalDebt_2024Q4
# TotalDebt_2025Q1
# TotalDebt_QoQ_24Q2_24Q3
# TotalDebt_QoQ_24Q3_24Q4
# TotalDebt_QoQ_24Q4_25Q1
# TotalDebt_QoQ_Rate
# TotalDebt_Rate
# TotalEquity_2024Q2
# TotalEquity_2024Q3
# TotalEquity_2024Q4
# TotalEquity_2025Q1
# TotalEquity_QoQ_24Q2_24Q3
# TotalEquity_QoQ_24Q3_24Q4
# TotalEquity_QoQ_24Q4_25Q1
# TotalEquity_QoQ_Rate
# TotalEquity_Rate
# TotalLiabilities_2024Q2
# TotalLiabilities_2024Q3
# TotalLiabilities_2024Q4
# TotalLiabilities_2025Q1
# TotalLiabilities_QoQ_24Q2_24Q3
# TotalLiabilities_QoQ_24Q3_24Q4
# TotalLiabilities_QoQ_24Q4_25Q1
# TotalLiabilities_QoQ_Rate
# TotalLiabilities_Rate
# Unemployment_2024Q1
# Unemployment_2024Q2
# Unemployment_2024Q3
# Unemployment_2024Q4
# Unemployment_2025Q1

# %% [markdown]
# Alright, let's now take a look at what columns have NaN values so we can start investigating why.

# %%
print(f"The column with the most NaN values has {df.isna().sum().max()} missing values.")
df.iloc[:,-80:-40].isna().sum()
# Out:
# The column with the most NaN values has 0 missing values.
# OtherOperatingExpense_QoQ_24Q2_24Q3    0
# OtherOperatingExpense_QoQ_24Q3_24Q4    0
# OtherOperatingExpense_QoQ_24Q4_25Q1    0
# KPI_CashFlow_QoQ_24Q2_24Q3             0
# KPI_CashFlow_QoQ_24Q3_24Q4             0
# KPI_CashFlow_QoQ_24Q4_25Q1             0
# KPI_DebtToEquityRatio_QoQ_24Q2_24Q3    0
# KPI_DebtToEquityRatio_QoQ_24Q3_24Q4    0
# KPI_DebtToEquityRatio_QoQ_24Q4_25Q1    0
# IncomeTaxExpense_QoQ_24Q2_24Q3         0
# IncomeTaxExpense_QoQ_24Q3_24Q4         0
# IncomeTaxExpense_QoQ_24Q4_25Q1         0
# Revenue_QoQ_24Q2_24Q3                  0
# Revenue_QoQ_24Q3_24Q4                  0
# Revenue_QoQ_24Q4_25Q1                  0
# KPI_NetProfitMargin_QoQ_24Q2_24Q3      0
# KPI_NetProfitMargin_QoQ_24Q3_24Q4      0
# KPI_NetProfitMargin_QoQ_24Q4_25Q1      0
# TotalAssets_QoQ_24Q2_24Q3              0
# TotalAssets_QoQ_24Q3_24Q4              0
# TotalAssets_QoQ_24Q4_25Q1              0
# CashFromOps_QoQ_24Q2_24Q3              0
# CashFromOps_QoQ_24Q3_24Q4              0
# CashFromOps_QoQ_24Q4_25Q1              0
# CapitalExpenditure_QoQ_Rate            0
# KPI_DebtToEquityRatio_QoQ_Rate         0
# CashAndSTInvestments_QoQ_Rate          0
# TotalAssets_QoQ_Rate                   0
# KPI_NetProfitMargin_QoQ_Rate           0
# KPI_Leverage_QoQ_Rate                  0
# LongTermDebt_QoQ_Rate                  0
# CashFromOps_QoQ_Rate                   0
# OtherOperatingExpense_QoQ_Rate         0
# InterestExpense_QoQ_Rate               0
# KPI_ReturnOnAssets_QoQ_Rate            0
# KPI_WorkingCapital_QoQ_Rate            0
# EPS_QoQ_Rate                           0
# TotalLiabilities_QoQ_Rate              0
# KPI_CurrentRatio_QoQ_Rate              0
# CurrentAssets_QoQ_Rate                 0
# dtype: int64

# %% [markdown]
# Alright, so it looks like the column with the most missing values is the Gross Profit Margin Calculation. So, let's filter our dataframe using masking and then investigate the columns in this.

# %%
missing_df = df[df['KPI_GrossProfitMargin_QoQ_24Q3_24Q4'].isna()]
missing_df.shape
# Out:
# (0, 282)

# %% [markdown]
# Let's also take a look and see if this captures most of the other NaN values in the dataframe

# %%
non_missing_df = df[~df['KPI_GrossProfitMargin_QoQ_24Q3_24Q4'].isna()]
print(f"Maximum number of missing columns after we address net margin is {non_missing_df.isna().sum().max()}")
# Out:
# Maximum number of missing columns after we address net margin is 0

# %% [markdown]
# Okay, so we will still having missing values after this that we will have to address.

# %%
columns_to_investigate = ['KPI_GrossProfitMargin_2024Q3','KPI_GrossProfitMargin_2024Q4','KPI_GrossProfitMargin_QoQ_24Q3_24Q4']
try:
    missing_df[columns_to_investigate].sample(10)
except:
    print("No missing values to show, so an empty dataframe is returned.")
# Out:
# No missing values to show, so an empty dataframe is returned.

# %% [markdown]
# After iterating through about 10 samples of 10, I can comfortably say that nearly all of these NaN values are due to a 0 Gross Profit Margin in the companies. So we will be able to address these pretty easily with a if denominator == 0 statement. Let's start investigating the nonmissing value dataframe for the ones that are left.

# %%
non_missing_df.iloc[:,-40:].isna().sum()
# Out:
# KPI_ReturnOnEquity_QoQ_Rate        0
# KPI_CashFlow_QoQ_Rate              0
# KPI_GrossProfitMargin_QoQ_Rate     0
# NetIncome_QoQ_Rate                 0
# OperatingIncome_QoQ_Rate           0
# CostOfRevenue_QoQ_Rate             0
# KPI_TotalAssetTurnover_QoQ_Rate    0
# CurrentLiabilities_QoQ_Rate        0
# Revenue_QoQ_Rate                   0
# TotalDebt_QoQ_Rate                 0
# IncomeTaxExpense_QoQ_Rate          0
# TotalEquity_QoQ_Rate               0
# KPI_WorkingCapital_Rate            0
# CurrentAssets_Rate                 0
# KPI_CurrentRatio_Rate              0
# KPI_ReturnOnEquity_Rate            0
# CapitalExpenditure_Rate            0
# CurrentLiabilities_Rate            0
# CashAndSTInvestments_Rate          0
# KPI_Leverage_Rate                  0
# KPI_TotalAssetTurnover_Rate        0
# CostOfRevenue_Rate                 0
# KPI_GrossProfitMargin_Rate         0
# KPI_ReturnOnAssets_Rate            0
# OperatingIncome_Rate               0
# InterestExpense_Rate               0
# TotalDebt_Rate                     0
# EPS_Rate                           0
# NetIncome_Rate                     0
# TotalEquity_Rate                   0
# TotalLiabilities_Rate              0
# LongTermDebt_Rate                  0
# OtherOperatingExpense_Rate         0
# KPI_CashFlow_Rate                  0
# KPI_DebtToEquityRatio_Rate         0
# IncomeTaxExpense_Rate              0
# Revenue_Rate                       0
# KPI_NetProfitMargin_Rate           0
# TotalAssets_Rate                   0
# CashFromOps_Rate                   0
# dtype: int64

# %% [markdown]
# Alright, now the most values are the income tax expense QoQ rate. So we can investigate this furter the important thing here is that we are looking for all of the QoQ values in order to find the line of best fit in order to get the slope.

# %%
missing_income = non_missing_df[non_missing_df['IncomeTaxExpense_QoQ_Rate'].isna()]
missing_income.shape
# Out:
# (0, 282)

# %%
columns_to_investigate = ['IncomeTaxExpense_QoQ_24Q2_24Q3','IncomeTaxExpense_QoQ_24Q3_24Q4','IncomeTaxExpense_QoQ_24Q4_25Q1','IncomeTaxExpense_QoQ_Rate']
missing_income[columns_to_investigate].head(10)
# Out:
# Empty DataFrame
# Columns: [IncomeTaxExpense_QoQ_24Q2_24Q3, IncomeTaxExpense_QoQ_24Q3_24Q4, IncomeTaxExpense_QoQ_24Q4_25Q1, IncomeTaxExpense_QoQ_Rate]
# Index: []

# %% [markdown]
# So here we have a bunch of NaN and inf which implies that the QoQ calculation is likely the culprit so let's investigate that further and see if it addresses this.

# %%
columns_to_investigate = ['IncomeTaxExpense_2024Q2','IncomeTaxExpense_2024Q3','IncomeTaxExpense_2024Q4','IncomeTaxExpense_2025Q1']
missing_income[columns_to_investigate].head(10)
# Out:
# Empty DataFrame
# Columns: [IncomeTaxExpense_2024Q2, IncomeTaxExpense_2024Q3, IncomeTaxExpense_2024Q4, IncomeTaxExpense_2025Q1]
# Index: []

# %% [markdown]
# Alright, once again, it looks like our big issue is when we have zeros. I think in all of our calculations we should address a 0.0 with a 0.00000001. I will adjust the QoQ functions to address this. and then run through this notebook again to see if we have addressed the issues.
