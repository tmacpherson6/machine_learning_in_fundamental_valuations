# %% [markdown]
# # Data Exploration
# This is an intial notebook to explore the data and run some basic machine learning to get baseline evaluation metrics that we can aim to imporve on. We will aim to use feature engineering to improve model performance.
#
# Goals of this notebook:
# Univariate Analysis:
# - Distributions
# - Summary Stats (mean, median, variance, skewness, kurtosis)
# - Outliers/Extreme values
# - Missing Values
#
# Bivariate Analysis:
# - Correlation heatmaps (feature redundancy)
# - Scatterplots (Sploms)
# - Cross-tabs for categorical data
#
# Supervised Learning:
# - Scikit-Learn for basic evaluation metrics

# %% [markdown]
# ## Libraries
# Let's start by loading in our libraries that we will be using for this notebebook.

# %%
# File system libraries
import os
from google.colab import drive

# Data Manipulation Libraries
import numpy as np
import pandas as pd

# Stat Libraries
import scipy.stats as stats

# Machine Learning Libraries
#import pycaret #Not working with this version of python
import sklearn

# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# %%
pd.set_option('display.float_format','{:.0f}'.format)

# %% [markdown]
# ## Load Data
# Next we will load the data used for our modelling. We will set this up so it's relatively easy to change the file name in case we decide to add/delete data in our main dataset.

# %%
# Mount the google drive
drive.mount('/content/drive')
# Navigate to the folder and set the file name
path = '/content/drive/MyDrive/Colab Notebooks/696 - Milestone II/696 - Milestone II - Shared/Dataset'

os.chdir(path)
os.getcwd()
os.listdir()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Russell_3000.csv',
#  'Russell_3000_Quarter_Annual_0913.csv',
#  'Russell_1000',
#  'Russel_3000_Quarter_Annual_0913.ipynb',
#  'Macroeconomics',
#  'Russell_3000_Quarterly_0917_five_more_variable.csv',
#  'Russel_3000_0917_five_more_variable.ipynb',
#  'Russell_3000_Merged.csv',
#  'Russell_3000_09-17_Merged_cleaned.csv',
#  'clean_data.ipynb',
#  'Russel_3000_09-17_merged_cleaned_KPIs.csv']

# %%
filename = 'Russell_3000_Merged.csv'
dataset = pd.read_csv(filename)
print(dataset.head())
# Out:
#   Ticker                        Name                  Sector OriginalTicker  \
# 0   NVDA                 NVIDIA CORP  Information Technology           NVDA
# 1   MSFT              MICROSOFT CORP  Information Technology           MSFT
# 2   AAPL                   APPLE INC  Information Technology           AAPL
# 3   AMZN              AMAZON COM INC  Consumer Discretionary           AMZN
# 4   META  META PLATFORMS INC CLASS A           Communication           META
#
#   YahooSymbol Asset Class  CashAndSTInvestments_2024Q2  \
# 0        NVDA      Equity                          NaN
# 1        MSFT      Equity                  18315000000
# 2        AAPL      Equity                  25565000000
# 3        AMZN      Equity                  71178000000
# 4        META      Equity                  32045000000
#
#    CashAndSTInvestments_2024Q3  CashAndSTInvestments_2024Q4  \
# 0                   8563000000                   9107000000
# 1                  20840000000                  17482000000
# 2                  29943000000                  30299000000
# 3                  75091000000                  78779000000
# 4                  43852000000                  43889000000
#
#    CashAndSTInvestments_2025Q1  ...  InterestExpense_2024Q2  \
# 0                   8589000000  ...                     NaN
# 1                  28828000000  ...               701000000
# 2                  28162000000  ...             21448000000
# 3                  66207000000  ...               589000000
# 4                  28750000000  ...               128000000
#
#    InterestExpense_2024Q3  InterestExpense_2024Q4  InterestExpense_2025Q1  \
# 0                61000000                61000000                61000000
# 1               582000000               594000000               594000000
# 2             14736000000             36330000000             24780000000
# 3               603000000               570000000               541000000
# 4               208000000               251000000               240000000
#
#    InterestExpense_2025Q2  OtherOperatingExpense_2024Q2  \
# 0                63000000                           NaN
# 1               615000000                   17118000000
# 2             23434000000                   14326000000
# 3               516000000                   59520000000
# 4               241000000                   16916000000
#
#   OtherOperatingExpense_2024Q3  OtherOperatingExpense_2024Q4  \
# 0                   3932000000                    4287000000
# 1                  14934000000                   16180000000
# 2                  14288000000                   15443000000
# 3                  60489000000                   67696000000
# 4                  15864000000                   16182000000
#
#    OtherOperatingExpense_2025Q1  OtherOperatingExpense_2025Q2
# 0                    4689000000                    5030000000
# 1                   16147000000                   18104000000
# 2                   15278000000                   15516000000
# 3                   60286000000                   67722000000
# 4                   17187000000                   18584000000
#
# [5 rows x 94 columns]

# %% [markdown]
# ## Dataset Exploration
#
# Let's start by looking at the dataset to get an idea of what we are working with.

# %%
print(f"We have {dataset.shape[0]} companies.")
print(f"\nCurrently we have {dataset.shape[1]} features")
# Out:
# We have 2600 companies.
#
# Currently we have 94 features

# %%
# Let's look at the comlumns in an easy to read format
columns = list(dataset.columns)
for column in columns:
    print(column)
print(f"\nCurrently we have {len(columns)} features")
# Out:
# Ticker
# Name
# Sector
# OriginalTicker
# YahooSymbol
# Asset Class
# CashAndSTInvestments_2024Q2
# CashAndSTInvestments_2024Q3
# CashAndSTInvestments_2024Q4
# CashAndSTInvestments_2025Q1
# CashAndSTInvestments_2025Q2
# CashFromOps_2024Q2
# CashFromOps_2024Q3
# CashFromOps_2024Q4
# CashFromOps_2025Q1
# CashFromOps_2025Q2
# Currency
# EPS_2024Q2
# EPS_2024Q3
# EPS_2024Q4
# EPS_2025Q1
# EPS_2025Q2
# Exchange
# Location
# LongTermDebt_2024Q2
# LongTermDebt_2024Q3
# LongTermDebt_2024Q4
# LongTermDebt_2025Q1
# LongTermDebt_2025Q2
# Market Value
# NetIncome_2024Q2
# NetIncome_2024Q3
# NetIncome_2024Q4
# NetIncome_2025Q1
# NetIncome_2025Q2
# Notional Value
# OperatingIncome_2024Q2
# OperatingIncome_2024Q3
# OperatingIncome_2024Q4
# OperatingIncome_2025Q1
# OperatingIncome_2025Q2
# Price
# Quantity
# Revenue_2024Q2
# Revenue_2024Q3
# Revenue_2024Q4
# Revenue_2025Q1
# Revenue_2025Q2
# ShortTermDebtOrCurrentLiab_2024Q2
# ShortTermDebtOrCurrentLiab_2024Q3
# ShortTermDebtOrCurrentLiab_2024Q4
# ShortTermDebtOrCurrentLiab_2025Q1
# ShortTermDebtOrCurrentLiab_2025Q2
# TotalAssets_2024Q2
# TotalAssets_2024Q3
# TotalAssets_2024Q4
# TotalAssets_2025Q1
# TotalAssets_2025Q2
# TotalEquity_2024Q2
# TotalEquity_2024Q3
# TotalEquity_2024Q4
# TotalEquity_2025Q1
# TotalEquity_2025Q2
# TotalLiabilities_2024Q2
# TotalLiabilities_2024Q3
# TotalLiabilities_2024Q4
# TotalLiabilities_2025Q1
# TotalLiabilities_2025Q2
# Weight (%)
# CapitalExpenditure_2024Q2
# CapitalExpenditure_2024Q3
# CapitalExpenditure_2024Q4
# CapitalExpenditure_2025Q1
# CapitalExpenditure_2025Q2
# CostOfRevenue_2024Q2
# CostOfRevenue_2024Q3
# CostOfRevenue_2024Q4
# CostOfRevenue_2025Q1
# CostOfRevenue_2025Q2
# IncomeTaxExpense_2024Q2
# IncomeTaxExpense_2024Q3
# IncomeTaxExpense_2024Q4
# IncomeTaxExpense_2025Q1
# IncomeTaxExpense_2025Q2
# InterestExpense_2024Q2
# InterestExpense_2024Q3
# InterestExpense_2024Q4
# InterestExpense_2025Q1
# InterestExpense_2025Q2
# OtherOperatingExpense_2024Q2
# OtherOperatingExpense_2024Q3
# OtherOperatingExpense_2024Q4
# OtherOperatingExpense_2025Q1
# OtherOperatingExpense_2025Q2
#
# Currently we have 94 features

# %% [markdown]
# ## Categorical Data Exploration
# Let's start with the first column which is the ticker. We should have all values here but we can confirm. We can look to make sure we have no duplicates by finding unique values and counting them to make sure we still have 2614 companies.

# %%
print(f'There are {dataset['Ticker'].isna().sum()} missing enteries in the Ticker column')

print(f'There are {dataset.shape[0] - dataset['Ticker'].nunique()} duplicated enteries in the Ticker column')
# Out:
# There are 0 missing enteries in the Ticker column
# There are 4 duplicated enteries in the Ticker column

# %% [markdown]
# Okay, so we clearly have some duplicate symbols. Let's see if we can address this just by dropping duplicate rows in the dataset.

# %%
dataset.drop_duplicates(inplace=True)
print(f"We now have {dataset.shape[0]} company enteries")
# Out:
# We now have 2600 company enteries

# %% [markdown]
# So this, addressed 4 enteries but we still have 14 that have the same ticker symbol. We will need to investigate these as to why they have the same symbol but different values in the columns.

# %%
duplicates = dataset.loc[dataset.duplicated('Ticker', keep=False)].sort_values('Ticker')
duplicates
# Out:
#      Ticker                               Name         Sector OriginalTicker  \
# 2587     --  NEXPOINT DIVERSIFIED CASH ACCRUAL    Real Estate             --
# 2591     --      ESC GCI LIBERTY INC SR ESCROW  Communication             --
# 2596     --     OMNIAB INC $15.00 VESTING Prvt    Health Care             --
# 2597     --     OMNIAB INC $12.50 VESTING Prvt    Health Care             --
# 2586   ADRO           CHINOOK THERAPEUTICS INC    Health Care           ADRO
# 2588   ADRO       CHINOOK THERAPEUTICS INC CVR    Health Care           ADRO
#
#      YahooSymbol Asset Class  CashAndSTInvestments_2024Q2  \
# 2587          --      Equity                          NaN
# 2591          --      Equity                          NaN
# 2596          --      Equity                          NaN
# 2597          --      Equity                          NaN
# 2586        ADRO      Equity                          NaN
# 2588        ADRO      Equity                          NaN
#
#       CashAndSTInvestments_2024Q3  CashAndSTInvestments_2024Q4  \
# 2587                          NaN                          NaN
# 2591                          NaN                          NaN
# 2596                          NaN                          NaN
# 2597                          NaN                          NaN
# 2586                          NaN                          NaN
# 2588                          NaN                          NaN
#
#       CashAndSTInvestments_2025Q1  ...  InterestExpense_2024Q2  \
# 2587                          NaN  ...                     NaN
# 2591                          NaN  ...                     NaN
# 2596                          NaN  ...                     NaN
# 2597                          NaN  ...                     NaN
# 2586                          NaN  ...                     NaN
# 2588                          NaN  ...                     NaN
#
#       InterestExpense_2024Q3  InterestExpense_2024Q4  InterestExpense_2025Q1  \
# 2587                     NaN                     NaN                     NaN
# 2591                     NaN                     NaN                     NaN
# 2596                     NaN                     NaN                     NaN
# 2597                     NaN                     NaN                     NaN
# 2586                     NaN                     NaN                     NaN
# 2588                     NaN                     NaN                     NaN
#
#       InterestExpense_2025Q2  OtherOperatingExpense_2024Q2  \
# 2587                     NaN                           NaN
# 2591                     NaN                           NaN
# 2596                     NaN                           NaN
# 2597                     NaN                           NaN
# 2586                     NaN                           NaN
# 2588                     NaN                           NaN
#
#      OtherOperatingExpense_2024Q3  OtherOperatingExpense_2024Q4  \
# 2587                          NaN                           NaN
# 2591                          NaN                           NaN
# 2596                          NaN                           NaN
# 2597                          NaN                           NaN
# 2586                          NaN                           NaN
# 2588                          NaN                           NaN
#
#       OtherOperatingExpense_2025Q1  OtherOperatingExpense_2025Q2
# 2587                           NaN                           NaN
# 2591                           NaN                           NaN
# 2596                           NaN                           NaN
# 2597                           NaN                           NaN
# 2586                           NaN                           NaN
# 2588                           NaN                           NaN
#
# [6 rows x 94 columns]

# %% [markdown]
# Okay, so most of the duplication was comming from the fact that we don't have a true ticker. However, every single entry in these duplicated symbols are missing all quantitative data, so we can remove them.

# %%
idx_remove = list(duplicates.index)
dataset.drop(index=idx_remove, inplace=True)
print(f"We now have {dataset.shape[0]} company enteries")
print(f'There are {dataset.shape[0] - dataset['Ticker'].nunique()} duplicated enteries in the Ticker column')
# Out:
# We now have 2594 company enteries
# There are 0 duplicated enteries in the Ticker column

# %% [markdown]
# Next, I see that there are multiple columns that have ticker information, we likely only need the main one. We also want to make sure all Asset classes are equity. So lets address that now.

# %%
dataset.drop(columns=['OriginalTicker','YahooSymbol'],inplace=True)
print(dataset['Asset Class'].unique())
# Out:
# ['Equity' 'Money Market' 'Cash' 'Cash Collateral and Margins' 'Futures']

# %% [markdown]
# Alright, so we have quite a few asset classes. Let's take a look at a few to make sure they aren't just misrepresented.

# %%
asset_class = 'Cash Collateral and Margins'
asset_class_df = dataset[dataset['Asset Class'] == asset_class]
asset_class_df.head()
# Out:
#     Ticker                       Name                   Sector  \
# 637  MSFUT  CASH COLLATERAL MSFUT USD  Cash and/or Derivatives
#
#                      Asset Class  CashAndSTInvestments_2024Q2  \
# 637  Cash Collateral and Margins                          NaN
#
#      CashAndSTInvestments_2024Q3  CashAndSTInvestments_2024Q4  \
# 637                          NaN                          NaN
#
#      CashAndSTInvestments_2025Q1  CashAndSTInvestments_2025Q2  \
# 637                          NaN                          NaN
#
#      CashFromOps_2024Q2  ...  InterestExpense_2024Q2  InterestExpense_2024Q3  \
# 637                 NaN  ...                     NaN                     NaN
#
#      InterestExpense_2024Q4  InterestExpense_2025Q1 InterestExpense_2025Q2  \
# 637                     NaN                     NaN                    NaN
#
#      OtherOperatingExpense_2024Q2  OtherOperatingExpense_2024Q3  \
# 637                           NaN                           NaN
#
#      OtherOperatingExpense_2024Q4  OtherOperatingExpense_2025Q1  \
# 637                           NaN                           NaN
#
#      OtherOperatingExpense_2025Q2
# 637                           NaN
#
# [1 rows x 92 columns]

# %% [markdown]
# Okay, there are very few enteries that are not equities and none of them contain quantitative data. So they can be eliminated as well.

# %%
dataset=dataset[dataset['Asset Class'] == 'Equity']
print(dataset['Asset Class'].unique())
dataset.drop(columns='Asset Class',inplace=True)
print(f'We now have {dataset.shape[0]} enteries and {dataset.shape[1]} features')
# Out:
# ['Equity']
# We now have 2589 enteries and 91 features

# %% [markdown]
# Next, let's jump to the currency column. This should all be in USD as we are focusing on US markets.

# %%
print(dataset['Currency'].unique())
dataset.drop(columns='Currency',inplace=True)
# Out:
# ['USD']

# %% [markdown]
# Let's take a look at the exchanges these companies are traded on. This can be diverse and may have an influence, so it is a categorical variable of interest.

# %%
print(dataset['Exchange'].unique())
#Let's look at how many are No Market
no_data = dataset[dataset['Exchange'] == 'NO MARKET (E.G. UNLISTED)']
print(len(no_data))

non_data = dataset[dataset['Exchange'] == 'Non-Nms Quotation Service (Nnqs)']
print(len(non_data))

#Alright, just one so we can likely drop both of these as they aren't on the main exchanges (NASDAQ, NYSE, CBOE, AMEX (nyse Mkt Llc)).
exchanges_to_drop = ['NO MARKET (E.G. UNLISTED)','Non-Nms Quotation Service (Nnqs)']
dataset = dataset[~dataset['Exchange'].isin(exchanges_to_drop)].copy()
print(f'We now have {dataset.shape[0]} rows')
# Out:
# ['NASDAQ' 'New York Stock Exchange Inc.' 'Cboe BZX' 'Nyse Mkt Llc'
#  'NO MARKET (E.G. UNLISTED)' 'Non-Nms Quotation Service (Nnqs)']
# 1
# 1
# We now have 2587 rows

# %% [markdown]
# Location may have a direct impact on corporate tax rates, So this will be an important column to keep.

# %%
print(dataset['Location'].isna().sum())
dataset['Location'].unique()
# Out:
# 0
# array(['United States', 'Sweden', 'Brazil', 'South Africa', 'Canada',
#        'Germany', 'Peru', 'Norway', 'Australia', 'United Kingdom',
#        'Panama', 'Guernsey', 'Bermuda', 'Israel', 'Singapore', 'Ireland',
#        'Monaco', 'Belgium'], dtype=object)

# %% [markdown]
# Okay, that all looks quite good so we can move on from categorical data to quantitative data.

# %% [markdown]
# ## Quantitative Data Exploration
#
# Lets start by looking at the revenue from the quarterly statements.

# %%
columns = ['Revenue_2024Q2',
           'Revenue_2024Q3',
           'Revenue_2024Q4',
           'Revenue_2025Q1',
           'Revenue_2025Q2']
revenue_data = dataset[columns]
revenue_data.head()
# Out:
#    Revenue_2024Q2  Revenue_2024Q3  Revenue_2024Q4  Revenue_2025Q1  \
# 0             NaN     30040000000     35082000000     39331000000
# 1     64727000000     65585000000     69632000000     70066000000
# 2     85777000000     94930000000    124300000000     95359000000
# 3    147977000000    158877000000    187792000000    155667000000
# 4     39071000000     40589000000     48385000000     42314000000
#
#    Revenue_2025Q2
# 0     44062000000
# 1     76441000000
# 2     94036000000
# 3    167702000000
# 4     47516000000

# %%
revenue_data.isna().sum()
# Out:
# Revenue_2024Q2    141
# Revenue_2024Q3     27
# Revenue_2024Q4     29
# Revenue_2025Q1     22
# Revenue_2025Q2     26
# dtype: int64

# %%
revenue_data.describe()
# Out:
#        Revenue_2024Q2  Revenue_2024Q3  Revenue_2024Q4  Revenue_2025Q1  \
# count            2446            2560            2558            2565
# mean       2009075481      2184084247      2227754124      2166909904
# std        7428095002      8391149726      8829283676      8418729732
# min       -1685000000     -1158957000     -1553908000     -5001300000
# 25%          99061000       105002000       110035250       109730000
# 50%         363542000       381615000       387156500       382083000
# 75%        1200918000      1305325000      1339999250      1308000000
# max      147977000000    169335000000    187792000000    180554000000
#
#        Revenue_2025Q2
# count            2561
# mean       2262469658
# std        8657833171
# min        -483000000
# 25%         115340000
# 50%         401258000
# 75%        1341000000
# max      167702000000

# %%
plt.hist(revenue_data['Revenue_2024Q2'],bins=200);

# %%
max_val = revenue_data['Revenue_2024Q2'].max()
print(max_val)
# Out:
# 147977000000.0

# %%
 dataset[dataset['Revenue_2024Q2']==max_val]
# Out:
#   Ticker            Name                  Sector  CashAndSTInvestments_2024Q2  \
# 3   AMZN  AMAZON COM INC  Consumer Discretionary                  71178000000
#
#    CashAndSTInvestments_2024Q3  CashAndSTInvestments_2024Q4  \
# 3                  75091000000                  78779000000
#
#    CashAndSTInvestments_2025Q1  CashAndSTInvestments_2025Q2  \
# 3                  66207000000                  57741000000
#
#    CashFromOps_2024Q2  CashFromOps_2024Q3  ...  InterestExpense_2024Q2  \
# 3         25281000000         25971000000  ...               589000000
#
#    InterestExpense_2024Q3  InterestExpense_2024Q4  InterestExpense_2025Q1  \
# 3               603000000               570000000               541000000
#
#    InterestExpense_2025Q2  OtherOperatingExpense_2024Q2  \
# 3               516000000                   59520000000
#
#    OtherOperatingExpense_2024Q3  OtherOperatingExpense_2024Q4  \
# 3                   60489000000                   67696000000
#
#   OtherOperatingExpense_2025Q1 OtherOperatingExpense_2025Q2
# 3                  60286000000                  67722000000
#
# [1 rows x 90 columns]

# %% [markdown]
# Amazon having the largest revenue makes sense. We can see that the data has a heavy right skew.

# %% [markdown]
# Lets continue by looking at the cash and short term investements from the quarterly statements.

# %%
columns = ['CashAndSTInvestments_2024Q2',
           'CashAndSTInvestments_2024Q3','CashAndSTInvestments_2024Q4','CashAndSTInvestments_2025Q1','CashAndSTInvestments_2025Q2']
cash_data = dataset[columns]
cash_data.head()
# Out:
#    CashAndSTInvestments_2024Q2  CashAndSTInvestments_2024Q3  \
# 0                          NaN                   8563000000
# 1                  18315000000                  20840000000
# 2                  25565000000                  29943000000
# 3                  71178000000                  75091000000
# 4                  32045000000                  43852000000
#
#    CashAndSTInvestments_2024Q4  CashAndSTInvestments_2025Q1  \
# 0                   9107000000                   8589000000
# 1                  17482000000                  28828000000
# 2                  30299000000                  28162000000
# 3                  78779000000                  66207000000
# 4                  43889000000                  28750000000
#
#    CashAndSTInvestments_2025Q2
# 0                  15234000000
# 1                  30242000000
# 2                  36269000000
# 3                  57741000000
# 4                  12005000000

# %%
cash_data.isna().sum()
# Out:
# CashAndSTInvestments_2024Q2    156
# CashAndSTInvestments_2024Q3     32
# CashAndSTInvestments_2024Q4     27
# CashAndSTInvestments_2025Q1     28
# CashAndSTInvestments_2025Q2     27
# dtype: int64

# %%
cash_data.describe()
# Out:
#        CashAndSTInvestments_2024Q2  CashAndSTInvestments_2024Q3  \
# count                         2431                         2555
# mean                    1798667628                   1755081853
# std                    15836044414                  13923975251
# min                              0                            0
# 25%                       70751000                     77016000
# 50%                      207976000                    223053000
# 75%                      604178500                    652985000
# max                   530819000000                 434260000000
#
#        CashAndSTInvestments_2024Q4  CashAndSTInvestments_2025Q1  \
# count                         2560                         2559
# mean                    1771824623                   1733513124
# std                    14260741145                  13689016283
# min                              0                         1000
# 25%                       78072750                     78172500
# 50%                      217962500                    211526000
# 75%                      683316750                    639478000
# max                   469317000000                 425903000000
#
#        CashAndSTInvestments_2025Q2
# count                         2560
# mean                    1766589388
# std                    14021617520
# min                           1000
# 25%                       78785750
# 50%                      212216000
# 75%                      663068750
# max                   420327000000

# %%
plt.hist(cash_data['CashAndSTInvestments_2024Q2'],bins=200);

# %% [markdown]
# We an see that clearly there is an outlier here by both the 'max' value and the skew of this histogram. So let's take a look at the max value.

# %%
max_val = cash_data['CashAndSTInvestments_2024Q2'].max()
print(max_val)
# Out:
# 530819000000.0

# %%
 dataset[dataset['CashAndSTInvestments_2024Q2']==max_val]
# Out:
#    Ticker                 Name      Sector  CashAndSTInvestments_2024Q2  \
# 10    JPM  JPMORGAN CHASE & CO  Financials                 530819000000
#
#     CashAndSTInvestments_2024Q3  CashAndSTInvestments_2024Q4  \
# 10                 434260000000                 469317000000
#
#     CashAndSTInvestments_2025Q1  CashAndSTInvestments_2025Q2  \
# 10                 425903000000                 420327000000
#
#     CashFromOps_2024Q2  CashFromOps_2024Q3  ...  InterestExpense_2024Q2  \
# 10         38469000000        -74081000000  ...             25767000000
#
#     InterestExpense_2024Q3  InterestExpense_2024Q4  InterestExpense_2025Q1  \
# 10             27011000000             24216000000             23580000000
#
#     InterestExpense_2025Q2  OtherOperatingExpense_2024Q2  \
# 10             25032000000                   25767000000
#
#     OtherOperatingExpense_2024Q3  OtherOperatingExpense_2024Q4  \
# 10                   27011000000                   24216000000
#
#    OtherOperatingExpense_2025Q1 OtherOperatingExpense_2025Q2
# 10                  23580000000                  25032000000
#
# [1 rows x 90 columns]

# %% [markdown]
# Okay, JPMorgan Chase is a company that we would expect to have very high cash and short term investments. I am going to look at an outside source to cross reference. I will look at the most recent 10Q statement from the SEC website: https://www.sec.gov/search-filings
#
# [Most recent JPM 10Q](https://https://www.sec.gov/ix?doc=/Archives/edgar/data/0000019617/000001961725000615/jpm-20250630.htm#i7f51d6660c094a199e33ebb8dd4036ff_169)
#
# Let's take a look at how many are over $100,000,000.

# %%
temp = dataset[dataset['CashAndSTInvestments_2024Q2'] > 100000000]
print(len(temp))
# Out:
# 1656

# %% [markdown]
# Next, lets take a look at the data that we will evenutally try to predict. Earnings per share.

# %%
columns = ['EPS_2024Q2',
           'EPS_2024Q3',
           'EPS_2024Q4',
           'EPS_2025Q1',
           'EPS_2025Q2']
eps_data = dataset[columns]
plt.hist(eps_data['EPS_2024Q2'],bins=200);

# %%
eps_data.describe()
# Out:
#        EPS_2024Q2  EPS_2024Q3  EPS_2024Q4  EPS_2025Q1  EPS_2025Q2
# count        2440        2534        2331        2534        2540
# mean            1           1           1           1           1
# std             5           5           8           3           4
# min           -76        -153        -275         -21         -78
# 25%            -0          -0          -0          -0          -0
# 50%             0           0           0           0           0
# 75%             1           1           1           1           1
# max           125         130         140          95         109

# %%
eps_data.head()
# Out:
#    EPS_2024Q2  EPS_2024Q3  EPS_2024Q4  EPS_2025Q1  EPS_2025Q2
# 0         NaN           1           1           1           1
# 1           3           3           3           3           4
# 2           1           1           2           2           2
# 3           1           1           2           2           2
# 4           5           6           8           6           7

# %% [markdown]
# We may want to get better accuracy with float values instead of integers here.

# %%
quarter = '2025Q2'
column = [f'Revenue_{quarter}',
           f'OperatingIncome_{quarter}',
           f'NetIncome_{quarter}',
           f'CashFromOps_{quarter}',
           f'CashAndSTInvestments_{quarter}',
           f'ShortTermDebtOrCurrentLiab_{quarter}',
           f'LongTermDebt_{quarter}',
           f'TotalAssets_{quarter}',
           f'TotalLiabilities_{quarter}',
           f'EPS_{quarter}'
           ]

splom_data = dataset[column].dropna()

columns = ['Revenue','Operating Income','Net Income','Cash From \nOperations','Cash and Short \nTerm Investments','Short Term Debt and \nCurrent Liabilities','Long Term Debt',' Total Assets','Total Liabilities','Earnings Per Share']

splom_data.columns = columns
g = sns.pairplot(splom_data, diag_kind="hist")
g.fig.suptitle(f"SPLOM of Quarterly Financial Data for {quarter}")
g.fig.subplots_adjust(top=0.95);

# %% [markdown]
# We can definitely see some linear correlations in this data. Let's draw up a correlation heatmap.

# %%
quarter_data = dataset[column]
quarter_data.columns = columns
corr = quarter_data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,cmap='viridis',cbar=True)
plt.title(f'Correlation Heat Map for {quarter} Financial Data');

# %% [markdown]
# Based on initial looks, raw funamentals per quarter look like they may be weak predictors on their own (will test this with some supervised models on raw data).
#
# ## Feature Engineering
# Let's start thinking about stronger predictive features.
#
# ### Profitability Ratios
# Operating margin = OperatingIncome/Revenue
# Net margin = Net Income/ Revenue
# Return on Assets (ROA)= Net Income/ Average Total Assets
# *Return on Equity (ROE) = Net Income/ (Average Assets - Average liabilities)
# *If we can get equity measures we can use the more accurate Net ROE = Profit/Average Equity for now we can use the proxy of assets - liabilities = equity.
# ### Liquidity and Leverage
# Current ratio = Cash and Short Term Investments/ Short Term Debt or Current Liabilities
# Debt/Assets = (Short Term Debt or Current Liabilities + Long Term Debt)/ Total Assets
# Debt/Equity = (Short Term Debt or Current Liabilities + Long Term Debt) / (Total Assets - Total Liabilities)
#
# ### Cash Flow Strength
# Cash Flow Margin = CashFromOps/Revenue
# Cash Conversion = CashFromOps/NetIncome
#
# ### Temporal Changes Quarter over Quarter
# For Every Feature:
# $\Delta F_t = \frac{F_t - F_{t-1}}{F_{t-1}}$ Where F = Feature.
#
# ### Rolling Averages/Volatility
# 4-quarter average growth rate
# Standard deviation of EPS or Revenue Growth
#
# ### Additional Data
# P/E Ratio = Price / Earnings Per Share
# P/S Ratio = Price / Revenue Per Share
# EV/EBITDA = Not sure if we can get this data.

# %% [markdown]
# ## Additional Infromation
# I see a column 'market value' and I just want to check to see if that is the market cap.

# %%
dataset[['Ticker','Market Value']].head()
# Out:
#   Ticker      Market Value
# 0   NVDA  1,066,994,615.04
# 1   MSFT  1,000,536,825.69
# 2   AAPL    938,729,828.14
# 3   AMZN    600,426,381.12
# 4   META    434,118,178.20

# %% [markdown]
# Okay, so this is the market cap. I think we can map this to a new feature called market cap as categorical. So let's create the mapping. We will use the approximate definitions from investopedia: https://www.investopedia.com/insights/understanding-small-and-big-cap-stocks/

# %%
# Turns out this has a bunch of text in it because its strings so we need to clean and convert to numeric. Lets drop $,',' and any other values.
caps = (dataset['Market Value']
      .astype(str)
      .str.replace(r'[^0-9.\-eE]', '', regex=True))
caps = pd.to_numeric(caps, errors='coerce')
print(caps)

# Create the market cap bins. Looks like the market value is in thousands of dollars so we need to actually adjust our bins down by 1000
bins = np.array([0, 50e6, 250e6, 2e9, 10e9, 200e9, np.inf]) / 1e3
# Create the labels for the market caps
labels = ['Nano-Cap','Micro-Cap','Small-Cap','Mid-Cap','Large-Cap','Mega-Cap']

# Apply to the dataset
dataset['Market Cap'] = pd.cut(caps, bins=bins, labels=labels, right=False, include_lowest=True)
# Out:
# 0      1066994615
# 1      1000536826
# 2       938729828
# 3       600426381
# 4       434118178
#           ...
# 2589         1463
# 2592           23
# 2593          316
# 2594          600
# 2595          701
# Name: Market Value, Length: 2587, dtype: float64

# %%
# Sanity Check to see if it worked
dataset[['Ticker','Market Value','Market Cap']].sample(5)
# Out:
#      Ticker  Market Value Market Cap
# 1668   DXPE    354,434.94  Small-Cap
# 1297   ALRM    692,044.98  Small-Cap
# 2003   MOFG    181,744.08  Micro-Cap
# 2017   URGN    176,362.80  Micro-Cap
# 519     SFM  3,668,013.09    Mid-Cap
